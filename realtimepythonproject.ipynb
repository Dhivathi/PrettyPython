# %%
# !pip install yfinance pandas_datareader
# Out:
# Requirement already satisfied: yfinance in c:\users\dhivya\anaconda3\lib\site-packages (0.2.38)
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\dhivya\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dhivya\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\dhivya\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dhivya\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhivya\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dhivya\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhivya\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhivya\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhivya\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhivya\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/109.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/109.5 kB ? eta -:--:--
#    ------------------------- ------------- 71.7/109.5 kB 653.6 kB/s eta 0:00:01
#    -------------------------------------- 109.5/109.5 kB 902.0 kB/s eta 0:00:00
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.10.0

# %%
import yfinance as yf
stock = yf.Ticker("AAPL")  # Using Apple's stock symbol
data = stock.history(period="1y")  # Fetching data for 1 year
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-05-15 00:00:00-04:00  172.245234  172.294972  170.564159  171.160995
# 2023-05-16 00:00:00-04:00  171.081416  172.225335  170.892418  171.160995
# 2023-05-17 00:00:00-04:00  170.802922  172.016463  169.519728  171.777740
# 2023-05-18 00:00:00-04:00  172.086101  174.314273  171.668322  174.125275
# 2023-05-19 00:00:00-04:00  175.458178  175.458178  174.015841  174.234680
# ...                               ...         ...         ...         ...
# 2024-05-07 00:00:00-04:00  183.201504  184.649537  181.074400  182.152924
# 2024-05-08 00:00:00-04:00  182.602329  182.822032  181.204216  182.492477
# 2024-05-09 00:00:00-04:00  182.312720  184.409882  181.863333  184.320007
# 2024-05-10 00:00:00-04:00  184.899994  185.089996  182.130005  183.050003
# 2024-05-13 00:00:00-04:00  185.440002  187.100006  184.619995  186.279999
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-05-15 00:00:00-04:00  37266700       0.00           0.0
# 2023-05-16 00:00:00-04:00  42110300       0.00           0.0
# 2023-05-17 00:00:00-04:00  57951600       0.00           0.0
# 2023-05-18 00:00:00-04:00  65496700       0.00           0.0
# 2023-05-19 00:00:00-04:00  55772400       0.00           0.0
# ...                             ...        ...           ...
# 2024-05-07 00:00:00-04:00  77305800       0.00           0.0
# 2024-05-08 00:00:00-04:00  45057100       0.00           0.0
# 2024-05-09 00:00:00-04:00  48983000       0.00           0.0
# 2024-05-10 00:00:00-04:00  50759500       0.25           0.0
# 2024-05-13 00:00:00-04:00  71998100       0.00           0.0
#
# [251 rows x 7 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-05-15 00:00:00-04:00  172.245249  172.294988  170.564174  171.161011
# 2023-05-16 00:00:00-04:00  171.081432  172.225350  170.892433  171.161011
# 2023-05-17 00:00:00-04:00  170.802922  172.016463  169.519728  171.777740
# 2023-05-18 00:00:00-04:00  172.086086  174.314258  171.668307  174.125259
# 2023-05-19 00:00:00-04:00  175.458194  175.458194  174.015856  174.234695
# ...                               ...         ...         ...         ...
# 2024-05-07 00:00:00-04:00  183.201504  184.649537  181.074400  182.152924
# 2024-05-08 00:00:00-04:00  182.602329  182.822032  181.204216  182.492477
# 2024-05-09 00:00:00-04:00  182.312720  184.409882  181.863333  184.320007
# 2024-05-10 00:00:00-04:00  184.899994  185.089996  182.130005  183.050003
# 2024-05-13 00:00:00-04:00  185.440002  187.100006  184.619995  186.279999
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023
# 2023-05-19 00:00:00-04:00  55772400       0.00           0.0      0.000628
# ...                             ...        ...           ...           ...
# 2024-05-07 00:00:00-04:00  77305800       0.00           0.0      0.003797
# 2024-05-08 00:00:00-04:00  45057100       0.00           0.0      0.001864
# 2024-05-09 00:00:00-04:00  48983000       0.00           0.0      0.010014
# 2024-05-10 00:00:00-04:00  50759500       0.25           0.0     -0.006890
# 2024-05-13 00:00:00-04:00  71998100       0.00           0.0      0.017645
#
# [251 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

data['Close'].plot(figsize=(12, 6), title="Stock Price Movement")
plt.show()

# %%
data['Volume'].plot(figsize=(12, 6), title="Volume Traded Over Time")
plt.show()

# %%
import seaborn as sns

stock_list = ["AAPL", "MSFT", "JPM", "PEP", "GOOGL"]
close_prices = pd.DataFrame()

for stock in stock_list:
   close_prices[stock] = yf.Ticker(stock).history(period="1y")['Close']

correlation = close_prices.pct_change().corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.show()

# %%
data['SMA50'] = data['Close'].rolling(window=50).mean()
data['SMA200'] = data['Close'].rolling(window=200).mean()

data[['Close', 'SMA50', 'SMA200']].plot(figsize=(12,6))
plt.title('Simple Moving Average')
plt.show()

# %%
data['EMA50'] = data['Close'].ewm(span=50, adjust=False).mean()
data['EMA200'] = data['Close'].ewm(span=200, adjust=False).mean()

data[['Close', 'EMA50', 'EMA200']].plot(figsize=(12,6))
plt.title('Exponential Moving Average')
plt.show()

# %%
data['SMA20'] = data['Close'].rolling(window=20).mean()
data['Upper'] = data['SMA20'] + 2*data['Close'].rolling(window=20).std()
data['Lower'] = data['SMA20'] - 2*data['Close'].rolling(window=20).std()

data[['Close', 'SMA20', 'Upper', 'Lower']].plot(figsize=(12,6))
plt.title('Bollinger Bands')
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(data['Close'], order=(5,1,0))

results = model.fit()

data['Forecast'] = results.predict(start=90, end=103, dynamic=True)


data[['Close', 'Forecast']].plot(figsize=(12,6))

plt.title('Stock Price Prediction using ARIMA')

plt.show()
# Out:
# C:\Users\Dhivya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dhivya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dhivya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
from scipy.optimize import minimize
import numpy as np

# Assuming stock_list contains the symbols of the stocks in the portfolio
returns = close_prices.pct_change()
mean_returns = returns.mean()
cov_matrix = returns.cov()
num_portfolios = 10000
risk_free_rate = 0.0178 # example value

# Portfolio optimization function
def portfolio_annualised_performance(weights, mean_returns, cov_matrix):
   returns = np.sum(mean_returns*weights ) *252
   std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
   return std, returns

# Minimize negative Sharpe Ratio to get optimal portfolio
def neg_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
   p_var, p_ret = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
   return -(p_ret - risk_free_rate) / p_var

# Constraints for optimization
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})

# Running the optimization
initial = [1./len(stock_list) for stock in stock_list]
bounds = tuple((0, 1) for asset in range(len(stock_list)))
result = minimize(neg_sharpe_ratio, initial, args=(mean_returns, cov_matrix, risk_free_rate), bounds=bounds, constraints=constraints)
result
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.8150337384367075
#        x: [ 0.000e+00  1.734e-01  6.886e-01  2.285e-16  1.380e-01]
#      nit: 7
#      jac: [ 5.323e-01 -1.264e-01 -1.287e-01  8.357e-01 -1.283e-01]
#     nfev: 43
#     njev: 7
